# %%
import pandas as pd
import  numpy as np
from matplotlib import pyplot as plt
import seaborn as sns

df = pd.read_csv(r'C:\Users\USER\Downloads\reg-33-data.csv')

# %%
df.head()
# Out:
#    id convention   height    max   cat2  number  usage region      length  \
# 0   1      CO-1A  4284.51  44907   CA-E   16669   US-7   RE-4  12471.1127
# 1   2       CO-C   806.88  48831   CA-A    8652  US-20  RE-15  10035.7085
# 2   3      CO-19  2859.80  40760  CA-16   23103  US-17  RE-1D  14442.6566
# 3   4      CO-2B  5823.87  33597   CA-9   17680  US-10  RE-1D  15121.4937
# 4   5       CO-5      NaN  29848   CA-9   24136  US-21   RE-4  18093.9147
#
#    code     power   item  weight country         target
# 0  CO-B  27351.36  IT-17   13722    CO-1   44098.106769
# 1  CO-E  42323.89  IT-1E   33779    CO-0   95567.294044
# 2  CO-5  30660.91  IT-14   26633   CO-23   48583.507153
# 3  CO-B  59456.24   IT-8   14537   CO-11  130572.202064
# 4  CO-4  46998.44   IT-5   21135   CO-1E   85768.812850

# %%
ratio = df['max']/df['number']

df['ratio'] = ratio

# %%
df.head()
# Out:
#    id convention   height    max   cat2  number  usage region      length  \
# 0   1      CO-1A  4284.51  44907   CA-E   16669   US-7   RE-4  12471.1127
# 1   2       CO-C   806.88  48831   CA-A    8652  US-20  RE-15  10035.7085
# 2   3      CO-19  2859.80  40760  CA-16   23103  US-17  RE-1D  14442.6566
# 3   4      CO-2B  5823.87  33597   CA-9   17680  US-10  RE-1D  15121.4937
# 4   5       CO-5      NaN  29848   CA-9   24136  US-21   RE-4  18093.9147
#
#    code     power   item  weight country         target     ratio
# 0  CO-B  27351.36  IT-17   13722    CO-1   44098.106769  2.694043
# 1  CO-E  42323.89  IT-1E   33779    CO-0   95567.294044  5.643897
# 2  CO-5  30660.91  IT-14   26633   CO-23   48583.507153  1.764273
# 3  CO-B  59456.24   IT-8   14537   CO-11  130572.202064  1.900283
# 4  CO-4  46998.44   IT-5   21135   CO-1E   85768.812850  1.236659

# %%
df.replace(to_replace="CA-E" , value="cat2_CA-0'")
# Out:
#           id convention   height    max        cat2  number  usage region  \
# 0          1      CO-1A  4284.51  44907  cat2_CA-0'   16669   US-7   RE-4
# 1          2       CO-C   806.88  48831        CA-A    8652  US-20  RE-15
# 2          3      CO-19  2859.80  40760       CA-16   23103  US-17  RE-1D
# 3          4      CO-2B  5823.87  33597        CA-9   17680  US-10  RE-1D
# 4          5       CO-5      NaN  29848        CA-9   24136  US-21   RE-4
# ...      ...        ...      ...    ...         ...     ...    ...    ...
# 10804  10805      CO-28  1901.75  49087        CA-4   10679   US-3  RE-1D
# 10805  10806      CO-1A  6365.25  37253        CA-1   19960   US-5   RE-5
# 10806  10807      CO-10  5918.89  30925       CA-13   27776  US-24  RE-17
# 10807  10808      CO-2B   503.09  47998       CA-17   25741   US-6  RE-17
# 10808  10809      CO-2F  6191.13  29149  cat2_CA-0'   19425   US-1  RE-1C
#
#            length  code     power   item  weight country         target  \
# ...

# %%
df1=df.drop(['convention', 'cat2', 'usage', 'region', 'code','item', 'country'], axis=1)

# %%
from matplotlib import pyplot as plt
# %matplotlib inline
df1.hist(bins=50, figsize=(20,15))
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10809 entries, 0 to 10808
# Data columns (total 9 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      10809 non-null  int64
#  1   height  8971 non-null   float64
#  2   max     10809 non-null  int64
#  3   number  10809 non-null  int64
#  4   length  10646 non-null  float64
#  5   power   10809 non-null  float64
#  6   weight  10809 non-null  int64
#  7   target  10809 non-null  float64
#  8   ratio   10809 non-null  float64
# dtypes: float64(5), int64(4)
# memory usage: 760.1 KB

# %%
median = df1['height'].median()
df1['height'].fillna(median,inplace=True)

# %%
mean = df1['length'].mean()
df1['length'].fillna(mean, inplace=True)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10809 entries, 0 to 10808
# Data columns (total 9 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      10809 non-null  int64
#  1   height  10809 non-null  float64
#  2   max     10809 non-null  int64
#  3   number  10809 non-null  int64
#  4   length  10809 non-null  float64
#  5   power   10809 non-null  float64
#  6   weight  10809 non-null  int64
#  7   target  10809 non-null  float64
#  8   ratio   10809 non-null  float64
# dtypes: float64(5), int64(4)
# memory usage: 760.1 KB

# %%
np.any(np.isnan(df1))
np.all(np.isfinite(df1))
# Out:
# True

# %%
df1 = df1.reset_index()

# %%
X = df1.drop(['target'], axis=1)
y =df1[['target']]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X, y, random_state= 42, test_size = 0.25)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train_scaled = sc.fit_transform(X_train)
X_test_scaled = sc.fit_transform(X_test)

# %%
X_train_scaled.shape
# Out:
# (8106, 9)

# %%
from sklearn.tree import DecisionTreeRegressor
model=DecisionTreeRegressor(random_state=42, max_depth=5)
model.fit(X_train_scaled,y_train)
# Out:
# DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=5,
#                       max_features=None, max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, presort='deprecated',
#                       random_state=42, splitter='best')

# %%
y_pred = model.predict(X_test)

# %%
from sklearn.metrics import mean_squared_error
mse = mean_squared_error(y_test, y_pred)
print(mse)
# Out:
# 17641926814.258595
